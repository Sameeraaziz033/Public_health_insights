# %% [markdown]
# # Pandas

# %% [markdown]
# ## Install

# %%
#!pip install pandas

# %% [markdown]
# ## Import

# %%
import pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# ## Loading data

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]],
#     sep=',',
#     delimiter=None,
#     header='infer',
#     names=None,
#     index_col=None,
#     usecols=None,
#     squeeze=False,
#     prefix=None,
#     mangle_dupe_cols=True,
#     dtype=None,
#     engine=None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression='infer',
#     thousands=None,
#     decimal: str = '.',
#     lineterminator=None,
#     quotechar='"',
#     quoting=0,
#     doublequote=True,
#     escapechar=None,
# ...

# %%
pd.read_csv('salaryy.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-376a72d4ed3b> in <module>
# ----> 1 pd.read_csv('salaryy.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
salary_df = pd.read_csv('salary.csv', na_values=['?'])
salary_df
# Out:
#     salary  gender departm  years   age  publications
# 0    86285       0     bio   26.0  64.0            72
# 1    77125       0     bio   28.0  58.0            43
# 2    71922       0     bio   10.0  38.0            23
# 3    70499       0     bio   16.0  46.0            64
# 4    66624       0     bio   11.0  41.0            23
# ..     ...     ...     ...    ...   ...           ...
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5
#
# [77 rows x 6 columns]

# %% [markdown]
# ## Ways to check the dataframe

# %%
salary_df.head()
# Out:
#    salary  gender departm  years   age  publications
# 0   86285       0     bio   26.0  64.0            72
# 1   77125       0     bio   28.0  58.0            43
# 2   71922       0     bio   10.0  38.0            23
# 3   70499       0     bio   16.0  46.0            64
# 4   66624       0     bio   11.0  41.0            23

# %%
salary_df.head(7)
# Out:
#    salary  gender departm  years   age  publications
# 0   86285       0     bio   26.0  64.0            72
# 1   77125       0     bio   28.0  58.0            43
# 2   71922       0     bio   10.0  38.0            23
# 3   70499       0     bio   16.0  46.0            64
# 4   66624       0     bio   11.0  41.0            23
# 5   64451       0     bio   23.0  60.0            44
# 6   64366       0     bio   23.0  53.0            22

# %%
salary_df.tail()
# Out:
#     salary  gender departm  years   age  publications
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5

# %%
salary_df.sample(5)
# Out:
#     salary  gender  departm  years   age  publications
# 8    58560       0      bio    8.0  38.0             8
# 57   64048       0  physics   23.0  53.0             4
# 9    58294       0      bio   20.0  50.0            12
# 44   74085       0     stat   11.0  41.0            33
# 34   79735       0    neuro   11.0  41.0            32

# %%
salary_df.columns
# Out:
# Index(['salary', 'gender', 'departm', 'years', 'age', 'publications'], dtype='object')

# %%
salary_df.index
# Out:
# RangeIndex(start=0, stop=77, step=1)

# %%
salary_df.shape
# Out:
# (77, 6)

# %%
salary_df.shape[1]
# Out:
# 6

# %%
salary_df.dtypes
# Out:
# salary            int64
# gender            int64
# departm          object
# years           float64
# age             float64
# publications      int64
# dtype: object

# %% [markdown]
# **Common `pandas` data types:**
#
# | Type | Description |
# | --- | :-- |
# | `float64` | Numpy **float** (decimal) type |
# | `Int64` | Numpy **integer** type |
# | `object` | Numpy type for storing **strings** |
# | `category` | pandas **categorical** type |
# | `bool` | Numpy **Boolean** type |
# | `datetime64[ns]` | NumPy **date** type |

# %%
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   salary        77 non-null     int64
#  1   gender        77 non-null     int64
#  2   departm       77 non-null     object
#  3   years         76 non-null     float64
#  4   age           76 non-null     float64
#  5   publications  77 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 3.7+ KB

# %%
salary_df.describe() # numerical
# Out:
#               salary     gender      years        age  publications
# count      77.000000  77.000000  76.000000  76.000000     77.000000
# mean    67748.519481   0.142857  14.973684  45.486842     21.831169
# std     15100.581435   0.387783   8.617770   9.005914     15.240530
# min     44687.000000   0.000000   1.000000  31.000000      3.000000
# 25%     57185.000000   0.000000   8.000000  38.000000      9.000000
# 50%     62607.000000   0.000000  14.000000  44.000000     19.000000
# 75%     75382.000000   0.000000  23.000000  53.000000     33.000000
# max    112800.000000   2.000000  34.000000  65.000000     72.000000

# %%
salary_df.describe(include='object')
# Out:
#        departm
# count       77
# unique       7
# top        bio
# freq        16

# %%
salary_df['departm'].describe()
# Out:
# count      77
# unique      7
# top       bio
# freq       16
# Name: departm, dtype: object

# %%
salary_df['departm'].unique()
# Out:
# array(['bio', 'chem', 'geol', 'neuro', 'stat', 'physics', 'math'],
#       dtype=object)

# %%
salary_df['departm'].nunique()
# Out:
# 7

# %%
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %%
salary_df['departm'].value_counts()
# Out:
# bio        16
# neuro      15
# stat       15
# chem       11
# physics     8
# math        8
# geol        4
# Name: departm, dtype: int64

# %%
salary_df['gender'].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
salary_df['gender'].value_counts()
# Out:
# 0    67
# 1     9
# 2     1
# Name: gender, dtype: int64

# %% [markdown]
# ## Selecting Column

# %%
salary_df.age # will not work if you have space
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %%
salary_df['age']
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %% [markdown]
# ## Three types
#
# - DataFrame
# - Series
# - For both you will have `index`

# %%
type(salary_df)
# Out:
# pandas.core.frame.DataFrame

# %%
salary_df
# Out:
#     salary  gender departm  years   age  publications
# 0    86285       0     bio   26.0  64.0            72
# 1    77125       0     bio   28.0  58.0            43
# 2    71922       0     bio   10.0  38.0            23
# 3    70499       0     bio   16.0  46.0            64
# 4    66624       0     bio   11.0  41.0            23
# ..     ...     ...     ...    ...   ...           ...
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5
#
# [77 rows x 6 columns]

# %%
salary_df['age']
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %%
type(salary_df['age'])
# Out:
# pandas.core.series.Series

# %%
students_df = pd.DataFrame({'name':['Zaina', 'Mustafa'],
                            'age':[20, 22]})
students_df
# Out:
#       name  age
# 0    Zaina   20
# 1  Mustafa   22

# %% [markdown]
# ## Create New Columns

# %%
salary_df['country'] = "USA"

# %%
salary_df
# Out:
#     salary  gender departm  years   age  publications country
# 0    86285       0     bio   26.0  64.0            72     USA
# 1    77125       0     bio   28.0  58.0            43     USA
# 2    71922       0     bio   10.0  38.0            23     USA
# 3    70499       0     bio   16.0  46.0            64     USA
# 4    66624       0     bio   11.0  41.0            23     USA
# ..     ...     ...     ...    ...   ...           ...     ...
# 72   53662       1   neuro    1.0  31.0             3     USA
# 73   57185       1    stat    9.0  39.0             7     USA
# 74   52254       1    stat    2.0  32.0             9     USA
# 75   61885       1    math   23.0  60.0             9     USA
# 76   49542       1    math    3.0  33.0             5     USA
#
# [77 rows x 7 columns]

# %%
salary_df['الدولة'] = "الولايات المتحدة" # not recommended
salary_df
# Out:
#     salary  gender departm  years   age  publications            الدولة  \
# 0    86285       0     bio   26.0  64.0            72  الولايات المتحدة
# 1    77125       0     bio   28.0  58.0            43  الولايات المتحدة
# 2    71922       0     bio   10.0  38.0            23  الولايات المتحدة
# 3    70499       0     bio   16.0  46.0            64  الولايات المتحدة
# 4    66624       0     bio   11.0  41.0            23  الولايات المتحدة
# ..     ...     ...     ...    ...   ...           ...               ...
# 72   53662       1   neuro    1.0  31.0             3  الولايات المتحدة
# 73   57185       1    stat    9.0  39.0             7  الولايات المتحدة
# 74   52254       1    stat    2.0  32.0             9  الولايات المتحدة
# 75   61885       1    math   23.0  60.0             9  الولايات المتحدة
# 76   49542       1    math    3.0  33.0             5  الولايات المتحدة
#
#     monthly salary     pop
# 0      7190.416667  1872.0
# 1      6427.083333  1204.0
# ...

# %%
salary_df['monthly salary'] = salary_df['salary']/12
salary_df
# Out:
#     salary  gender departm  years   age  publications country الدولة  \
# 0    86285       0     bio   26.0  64.0            72     USA    USA
# 1    77125       0     bio   28.0  58.0            43     USA    USA
# 2    71922       0     bio   10.0  38.0            23     USA    USA
# 3    70499       0     bio   16.0  46.0            64     USA    USA
# 4    66624       0     bio   11.0  41.0            23     USA    USA
# ..     ...     ...     ...    ...   ...           ...     ...    ...
# 72   53662       1   neuro    1.0  31.0             3     USA    USA
# 73   57185       1    stat    9.0  39.0             7     USA    USA
# 74   52254       1    stat    2.0  32.0             9     USA    USA
# 75   61885       1    math   23.0  60.0             9     USA    USA
# 76   49542       1    math    3.0  33.0             5     USA    USA
#
#     monthly_salary  monthly salary
# 0      7190.416667     7190.416667
# 1      6427.083333     6427.083333
# ...

# %%
salary_df['pop'] = salary_df['years'] * salary_df['publications']
salary_df
# Out:
#     salary  gender departm  years   age  publications country الدولة  \
# 0    86285       0     bio   26.0  64.0            72     USA    USA
# 1    77125       0     bio   28.0  58.0            43     USA    USA
# 2    71922       0     bio   10.0  38.0            23     USA    USA
# 3    70499       0     bio   16.0  46.0            64     USA    USA
# 4    66624       0     bio   11.0  41.0            23     USA    USA
# ..     ...     ...     ...    ...   ...           ...     ...    ...
# 72   53662       1   neuro    1.0  31.0             3     USA    USA
# 73   57185       1    stat    9.0  39.0             7     USA    USA
# 74   52254       1    stat    2.0  32.0             9     USA    USA
# 75   61885       1    math   23.0  60.0             9     USA    USA
# 76   49542       1    math    3.0  33.0             5     USA    USA
#
#     monthly_salary  monthly salary     pop
# 0      7190.416667     7190.416667  1872.0
# 1      6427.083333     6427.083333  1204.0
# ...

# %% [markdown]
# ## Droping / Removing Columns

# %%
salary_df.drop(columns= ['monthly_salary', 'country'])# Drop it from this copy
# Out:
#     salary  gender departm  years   age  publications الدولة  monthly salary  \
# 0    86285       0     bio   26.0  64.0            72    USA     7190.416667
# 1    77125       0     bio   28.0  58.0            43    USA     6427.083333
# 2    71922       0     bio   10.0  38.0            23    USA     5993.500000
# 3    70499       0     bio   16.0  46.0            64    USA     5874.916667
# 4    66624       0     bio   11.0  41.0            23    USA     5552.000000
# ..     ...     ...     ...    ...   ...           ...    ...             ...
# 72   53662       1   neuro    1.0  31.0             3    USA     4471.833333
# 73   57185       1    stat    9.0  39.0             7    USA     4765.416667
# 74   52254       1    stat    2.0  32.0             9    USA     4354.500000
# 75   61885       1    math   23.0  60.0             9    USA     5157.083333
# 76   49542       1    math    3.0  33.0             5    USA     4128.500000
#
#        pop
# 0   1872.0
# 1   1204.0
# ...

# %%
salary_df.drop(columns= ['monthly_salary', 'country'], inplace=True) # this will remove it from the RAM

# %%
salary_df
# Out:
#     salary  gender departm  years   age  publications الدولة  monthly salary  \
# 0    86285       0     bio   26.0  64.0            72    USA     7190.416667
# 1    77125       0     bio   28.0  58.0            43    USA     6427.083333
# 2    71922       0     bio   10.0  38.0            23    USA     5993.500000
# 3    70499       0     bio   16.0  46.0            64    USA     5874.916667
# 4    66624       0     bio   11.0  41.0            23    USA     5552.000000
# ..     ...     ...     ...    ...   ...           ...    ...             ...
# 72   53662       1   neuro    1.0  31.0             3    USA     4471.833333
# 73   57185       1    stat    9.0  39.0             7    USA     4765.416667
# 74   52254       1    stat    2.0  32.0             9    USA     4354.500000
# 75   61885       1    math   23.0  60.0             9    USA     5157.083333
# 76   49542       1    math    3.0  33.0             5    USA     4128.500000
#
#        pop
# 0   1872.0
# 1   1204.0
# ...

# %% [markdown]
# ## Save the data

# %%
salary_df.to_csv('new_salary.csv')

# %% [markdown]
# ## Renaming

# %%
salary_df.monthly salary
# Out:
#   File "<ipython-input-86-2b83990be923>", line 1
#     salary_df.monthly salary
#                            ^
# SyntaxError: invalid syntax

# %%
salary_df.pop
# Out:
# <bound method NDFrame.pop of     salary  gender departm  years   age  publications            الدولة  \
# 0    86285       0     bio   26.0  64.0            72  الولايات المتحدة
# 1    77125       0     bio   28.0  58.0            43  الولايات المتحدة
# 2    71922       0     bio   10.0  38.0            23  الولايات المتحدة
# 3    70499       0     bio   16.0  46.0            64  الولايات المتحدة
# 4    66624       0     bio   11.0  41.0            23  الولايات المتحدة
# ..     ...     ...     ...    ...   ...           ...               ...
# 72   53662       1   neuro    1.0  31.0             3  الولايات المتحدة
# 73   57185       1    stat    9.0  39.0             7  الولايات المتحدة
# 74   52254       1    stat    2.0  32.0             9  الولايات المتحدة
# 75   61885       1    math   23.0  60.0             9  الولايات المتحدة
# 76   49542       1    math    3.0  33.0             5  الولايات المتحدة
#
#     monthly salary     pop
# 0      7190.416667  1872.0
# ...

# %%
salary_df.الدولة
# Out:
# 0     الولايات المتحدة
# 1     الولايات المتحدة
# 2     الولايات المتحدة
# 3     الولايات المتحدة
# 4     الولايات المتحدة
#             ...
# 72    الولايات المتحدة
# 73    الولايات المتحدة
# 74    الولايات المتحدة
# 75    الولايات المتحدة
# 76    الولايات المتحدة
# Name: الدولة, Length: 77, dtype: object

# %%
salary_df['monthly salary']
# Out:
# 0     7190.416667
# 1     6427.083333
# 2     5993.500000
# 3     5874.916667
# 4     5552.000000
#          ...
# 72    4471.833333
# 73    4765.416667
# 74    4354.500000
# 75    5157.083333
# 76    4128.500000
# Name: monthly salary, Length: 77, dtype: float64

# %%
salary_df['pop']
# Out:
# 0     1872.0
# 1     1204.0
# 2      230.0
# 3     1024.0
# 4      253.0
#        ...
# 72       3.0
# 73      63.0
# 74      18.0
# 75     207.0
# 76      15.0
# Name: pop, Length: 77, dtype: float64

# %%
dic = {'الدولة':'country',
      'monthly salary':'monthly_salary',
      'pop':'pop_per_year_ratio'}
dic
# Out:
# {'الدولة': 'country',
#  'monthly salary': 'monthly_salary',
#  'pop': 'pop_per_year_ratio'}

# %%
salary_df.rename(columns=dic)
# Out:
#     salary  gender departm  years   age  publications           country  \
# 0    86285       0     bio   26.0  64.0            72  الولايات المتحدة
# 1    77125       0     bio   28.0  58.0            43  الولايات المتحدة
# 2    71922       0     bio   10.0  38.0            23  الولايات المتحدة
# 3    70499       0     bio   16.0  46.0            64  الولايات المتحدة
# 4    66624       0     bio   11.0  41.0            23  الولايات المتحدة
# ..     ...     ...     ...    ...   ...           ...               ...
# 72   53662       1   neuro    1.0  31.0             3  الولايات المتحدة
# 73   57185       1    stat    9.0  39.0             7  الولايات المتحدة
# 74   52254       1    stat    2.0  32.0             9  الولايات المتحدة
# 75   61885       1    math   23.0  60.0             9  الولايات المتحدة
# 76   49542       1    math    3.0  33.0             5  الولايات المتحدة
#
#     monthly_salary  pop_per_year_ratio
# 0      7190.416667              1872.0
# ...

# %%
salary_df
# Out:
#     salary  gender departm  years   age  publications            الدولة  \
# 0    86285       0     bio   26.0  64.0            72  الولايات المتحدة
# 1    77125       0     bio   28.0  58.0            43  الولايات المتحدة
# 2    71922       0     bio   10.0  38.0            23  الولايات المتحدة
# 3    70499       0     bio   16.0  46.0            64  الولايات المتحدة
# 4    66624       0     bio   11.0  41.0            23  الولايات المتحدة
# ..     ...     ...     ...    ...   ...           ...               ...
# 72   53662       1   neuro    1.0  31.0             3  الولايات المتحدة
# 73   57185       1    stat    9.0  39.0             7  الولايات المتحدة
# 74   52254       1    stat    2.0  32.0             9  الولايات المتحدة
# 75   61885       1    math   23.0  60.0             9  الولايات المتحدة
# 76   49542       1    math    3.0  33.0             5  الولايات المتحدة
#
#     monthly salary     pop
# 0      7190.416667  1872.0
# 1      6427.083333  1204.0
# ...

# %%
salary_df.rename(columns=dic, inplace=True)

# %%
salary_df
# Out:
#     salary  gender departm  years   age  publications           country  \
# 0    86285       0     bio   26.0  64.0            72  الولايات المتحدة
# 1    77125       0     bio   28.0  58.0            43  الولايات المتحدة
# 2    71922       0     bio   10.0  38.0            23  الولايات المتحدة
# 3    70499       0     bio   16.0  46.0            64  الولايات المتحدة
# 4    66624       0     bio   11.0  41.0            23  الولايات المتحدة
# ..     ...     ...     ...    ...   ...           ...               ...
# 72   53662       1   neuro    1.0  31.0             3  الولايات المتحدة
# 73   57185       1    stat    9.0  39.0             7  الولايات المتحدة
# 74   52254       1    stat    2.0  32.0             9  الولايات المتحدة
# 75   61885       1    math   23.0  60.0             9  الولايات المتحدة
# 76   49542       1    math    3.0  33.0             5  الولايات المتحدة
#
#     monthly_salary  pop_per_year_ratio
# 0      7190.416667              1872.0
# ...

# %% [markdown]
# ## Mapping values

# %%
gender_dic = {0:'Male',
             1:'Female'}

# %%
salary_df['gender'].map(gender_dic)
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 72    Female
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# Name: gender, Length: 77, dtype: object

# %%
salary_df['gender']
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 72    1
# 73    1
# 74    1
# 75    1
# 76    1
# Name: gender, Length: 77, dtype: int64

# %%
#salary_df['gender'] = salary_df['gender'].map(gender_dic)

# %% [markdown]
# Why we change it?

# %%
salary_df['gender'].value_counts()
# Out:
# 0    67
# 1     9
# 2     1
# Name: gender, dtype: int64

# %%
salary_df['gender'].value_counts().plot(kind='pie');

# %%
salary_df['gender'].value_counts().plot(kind='bar');

# %% [markdown]
# ## Dealing with missing values

# %%
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   salary              77 non-null     int64
#  1   gender              76 non-null     object
#  2   departm             77 non-null     object
#  3   years               76 non-null     float64
#  4   age                 76 non-null     float64
#  5   publications        77 non-null     int64
#  6   country             77 non-null     object
#  7   monthly_salary      77 non-null     float64
#  8   pop_per_year_ratio  76 non-null     float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 5.5+ KB

# %%
salary_df.isnull()
# Out:
#     salary  gender  departm  years    age  publications  country  \
# 0    False   False    False  False  False         False    False
# 1    False   False    False  False  False         False    False
# 2    False   False    False  False  False         False    False
# 3    False   False    False  False  False         False    False
# 4    False   False    False  False  False         False    False
# ..     ...     ...      ...    ...    ...           ...      ...
# 72   False   False    False  False  False         False    False
# 73   False   False    False  False  False         False    False
# 74   False   False    False  False  False         False    False
# 75   False   False    False  False  False         False    False
# 76   False   False    False  False  False         False    False
#
#     monthly_salary  pop_per_year_ratio
# 0            False               False
# 1            False               False
# 2            False               False
# ...

# %%
salary_df.isnull().sum()
# Out:
# salary                0
# gender                1
# departm               0
# years                 1
# age                   1
# publications          0
# country               0
# monthly_salary        0
# pop_per_year_ratio    1
# dtype: int64

# %%
salary_df.isnull().sum().sum()
# Out:
# 4

# %%
lst = [False, True, False, True]#0, 1, 0, 1
sum(lst)
# Out:
# 2

# %%
l = [0, 1, 0, 1]
sum(l)
# Out:
# 2

# %% [markdown]
# - Fill it -> Exist (in real life) but not recorded in my data
# - Drop it
# - Keep it

# %%
salary_df.fillna(0)#.isnull().sum() not recommended
# Out:
# salary                0
# gender                0
# departm               0
# years                 0
# age                   0
# publications          0
# country               0
# monthly_salary        0
# pop_per_year_ratio    0
# dtype: int64

# %%
salary_df.age.mean()
# Out:
# 45.48684210526316

# %%
salary_df.age.median()
# Out:
# 44.0

# %%
salary_df.age.fillna(44)# inplace=True
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %%
salary_df.age.fillna(salary_df.age.median())

# %%
salary_df.gender.mode()
# Out:
# 0    Male
# dtype: object

# %%
salary_df.gender.fillna("Male", inplace=True)

# %%
salary_df.isnull().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Length: 77, dtype: bool

# %%
salary_df[salary_df.isnull().any(axis=1)]
# Out:
#     salary gender departm  years   age  publications           country  \
# 18   64762   Male    chem   25.0   NaN            29  الولايات المتحدة
# 24  104828   Male    geol    NaN  50.0            44  الولايات المتحدة
# 67   53517    NaN    math    5.0  35.0             5  الولايات المتحدة
#
#     monthly_salary  pop_per_year_ratio
# 18     5396.833333               725.0
# 24     8735.666667                 NaN
# 67     4459.750000                25.0

# %% [raw]
# wather
#
# 7  23
# 8  24
# 9
# 10 23
#
#
# 11 44

# %% [markdown]
# `bfill` and `ffill`

# %%
salary_df.ffill() # doesn't make sence with employees

# %% [markdown]
# Drop it

# %%
salary_df.dropna() # inplace=True
# Out:
#     salary  gender departm  years   age  publications           country  \
# 0    86285    Male     bio   26.0  64.0            72  الولايات المتحدة
# 1    77125    Male     bio   28.0  58.0            43  الولايات المتحدة
# 2    71922    Male     bio   10.0  38.0            23  الولايات المتحدة
# 3    70499    Male     bio   16.0  46.0            64  الولايات المتحدة
# 4    66624    Male     bio   11.0  41.0            23  الولايات المتحدة
# ..     ...     ...     ...    ...   ...           ...               ...
# 72   53662  Female   neuro    1.0  31.0             3  الولايات المتحدة
# 73   57185  Female    stat    9.0  39.0             7  الولايات المتحدة
# 74   52254  Female    stat    2.0  32.0             9  الولايات المتحدة
# 75   61885  Female    math   23.0  60.0             9  الولايات المتحدة
# 76   49542  Female    math    3.0  33.0             5  الولايات المتحدة
#
#     monthly_salary  pop_per_year_ratio
# 0      7190.416667              1872.0
# ...

# %%
salary_df['status'] =

# %% [markdown]
# ## Change the data types

# %%
salary_df.dtypes
# Out:
# salary                  int64
# gender                 object
# departm                object
# years                 float64
# age                   float64
# publications            int64
# country                object
# monthly_salary        float64
# pop_per_year_ratio    float64
# dtype: object

# %%
salary_df['departm'] = salary_df['departm'].astype('category')

# %%
salary_df['monthly_salary'] = salary_df['monthly_salary'].astype('int')
salary_df['monthly_salary']
# Out:
# 0     7190
# 1     6427
# 2     5993
# 3     5874
# 4     5552
#       ...
# 72    4471
# 73    4765
# 74    4354
# 75    5157
# 76    4128
# Name: monthly_salary, Length: 77, dtype: int32
