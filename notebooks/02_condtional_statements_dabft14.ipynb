# %% [markdown]
# # Conditional Statement

# %% [markdown]
# ## IF

# %% [markdown]
# ![image.png](attachment:d82ad0b9-5582-44b4-9f84-458e7d56928b.png)

# %%
age = 10 # assignment operator

# %%
age == 100 # comparision opesrators
# Out:
# False

# %%
answer = input("what's 2+2?")

if answer == '4':
    print("you are right")
    print()
    x = 2
# Out:
# what's 2+2? 100

# %%
answer = input("what's 2+2?")

if answer == '4':
    print("you are right")

print("Meaw")
# Out:
# what's 2+2? 4
# you are right
# Meaw

# %% [markdown]
# ## Alternative execution

# %% [markdown]
# ![image.png](attachment:907bd5e6-688d-401d-94c3-b3c37190b135.png)

# %%
answer = input("what's 2+2")

if answer == '4':
    print("You are right")
else:
    print("Try again")
# Out:
# what's 2+2 100
# Try again

# %% [markdown]
# ## Chained conditions

# %% [markdown]
# ![image.png](attachment:bb112f1a-8cab-435b-ba99-2b301c570959.png)

# %%
answer = input("what's 2+2?")
type(answer)
# Out:
# what's 2+2? 100
# str

# %%
answer = input("what's 2+2?")
answer = int(answer)
type(answer)
# Out:
# what's 2+2? 4
# int

# %%
answer = input("what's 2+2?")
answer = float(answer)

if answer == 4:
    print("You are right")
elif (answer > 2) and  (answer < 6):
    print("Almost there")
else:
    print("Looooooooser")
# Out:
# what's 2+2? 4.1
# Almost there

# %%
2 < answer < 6
# Out:
# False

# %%
4 == 4.0
# Out:
# True

# %% [markdown]
# ## Boolean expression

# %%
age = 10
# Out:
# 10

# %%
age > 0
# Out:
# True

# %%
age < 100
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ### Comparision operators

# %% [raw]
# >
# <
# >=
# <=
# != not equal
# == equal

# %%
age == 10.1
# Out:
# False

# %% [markdown]
# ### Logical operators

# %% [raw]
# and
# or
# not

# %%
(age > 0) and (age < 100)
# Out:
# True

# %%
num = 10

(num==3) or (num== 5)
# Out:
# False

# %% [raw]
# grade = 88
#
# 100-90  A
# 90-80   B
# 80-70   C
# 70-60   D
# < 60    F

# %%
grade = input("what's your grade?")
grade = float(grade)


if grade <= 100 and grade>= 90:
    print("A")
elif grade < 90 and grade>= 80:
    print("B")
elif grade < 80 and grade>= 70:
    print("C")
elif grade < 70 and grade>= 60:
    print("D")
else:
    print("F")
# Out:
# what's your grade? 50
# F

# %%
grade = input("what's your grade?")
grade = float(grade)


if grade <= 100 and grade>= 90:
    print("A")
elif grade < 90 and grade>= 80:
    print("B")
elif grade < 80 and grade>= 70:
    print("C")
elif grade < 70 and grade>= 60:
    print("D")
else:
    print("F")
# Out:
# what's your grade? 99
# A

# %%
grade = input("what's your grade?")
grade = float(grade)


if  grade>= 90:
    print("A")
elif  grade>= 80:
    print("B")
elif grade>= 70:
    print("C")
elif grade>= 60:
    print("D")
else:
    print("F")
# Out:
# what's your grade? 50
# F

# %%
grade = input("what's your grade?")
grade = float(grade)


if  grade>= 90:
    print("A")
if  grade>= 80:
    print("B")
if grade>= 70:
    print("C")
if grade>= 60:
    print("D")
else:
    print("F")
# Out:
# what's your grade? 100
# A
# B
# C
# D

# %%
grade = input("what's your grade?")
grade = float(grade)

if grade > 100 or grade < 0:
    print('invalid')
elif  grade>= 90:
    print("A")
elif  grade>= 80:
    print("B")
elif grade>= 70:
    print("C")
elif grade>= 60:
    print("D")

else:
    print("F")
# Out:
# what's your grade? 60
# D

# %%
grade_pass = 101

if grade_pass > 90 and  grade_pass <= 100 :
  print ("A")
elif grade_pass <90 and grade_pass >= 80 :
  print ("B")
elif grade_pass  <80 and grade_pass  >= 70 :
    print ("C")
elif grade_pass  <70 and grade_pass  >=60 :
    print("D")
elif grade_pass >100 :
    print ("NA")
else :
    print("F")
