# %% [markdown]
# # Filtering and Sorting

# %% [markdown]
# The 'imdb_1000.csv' dataframe contains information about the top-rated [IMDb](https://www.imdb.com/) movies

# %%
import pandas as pd

# %%
movies = pd.read_csv('imdb_1000.csv')
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
movies.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# ## 1. Sorting a Series

# %% [markdown]
# Documentation for [`sort_values`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.sort_values.html) for a Series.

# %% [markdown]
# **Sorting by value:**

# %%
movies['title'].sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies['title'].sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
movies['title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies['content_rating'].sort_values()
# Out:
# 253    APPROVED
# 52     APPROVED
# 107    APPROVED
# 612    APPROVED
# 58     APPROVED
#          ...
# 86            X
# 486           X
# 187         NaN
# 649         NaN
# 936         NaN
# Name: content_rating, Length: 979, dtype: object

# %%
movies['content_rating'].sort_values(na_position='first')
# Out:
# 187         NaN
# 649         NaN
# 936         NaN
# 253    APPROVED
# 52     APPROVED
#          ...
# 802     UNRATED
# 913           X
# 387           X
# 86            X
# 486           X
# Name: content_rating, Length: 979, dtype: object

# %% [markdown]
# **Sorting by index**

# %%
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# Documentation for [sort_index](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_index.html)

# %%
# set 'title' as index
movies.set_index('title', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 # set 'title' as index
# ----> 2 movies.set_index('title', inplace=True)
#
# File ~\anaconda3\envs\ga\lib\site-packages\pandas\core\frame.py:6129, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6126                 missing.append(col)
#    6128 if missing:
# -> 6129     raise KeyError(f"None of {missing} are in the columns")
#    6131 if inplace:
#    6132     frame = self
#
# KeyError: "None of ['title'] are in the columns"

# %% [markdown]
# Any Series can also be sorted by its index:

# %%
movies['star_rating'].sort_values()
# Out:
# title
# Wall Street                 7.4
# Take Shelter                7.4
# Far from Heaven             7.4
# Eraserhead                  7.4
# Frances Ha                  7.4
#                            ...
# Pulp Fiction                8.9
# The Dark Knight             9.0
# The Godfather: Part II      9.1
# The Godfather               9.2
# The Shawshank Redemption    9.3
# Name: star_rating, Length: 979, dtype: float64

# %%
movies['star_rating'].sort_index()
# Out:
# title
# (500) Days of Summer     7.8
# 12 Angry Men             8.9
# 12 Years a Slave         8.1
# 127 Hours                7.6
# 2001: A Space Odyssey    8.3
#                         ...
# Zero Dark Thirty         7.4
# Zodiac                   7.7
# Zombieland               7.7
# Zulu                     7.8
# [Rec]                    7.5
# Name: star_rating, Length: 979, dtype: float64

# %%
movies.set_index('content_rating', inplace=True)
movies
# Out:
#                                                           title  star_rating  \
# content_rating
# R                                      The Shawshank Redemption          9.3
# R                                                 The Godfather          9.2
# R                                        The Godfather: Part II          9.1
# PG-13                                           The Dark Knight          9.0
# R                                                  Pulp Fiction          8.9
# ...                                                         ...          ...
# PG                                                      Tootsie          7.4
# PG                                  Back to the Future Part III          7.4
# PG-13           Master and Commander: The Far Side of the World          7.4
# PG                                                  Poltergeist          7.4
# R                                                   Wall Street          7.4
#
#                     genre  duration  \
# content_rating
# R                   Crime       142
# R                   Crime       175
# R                   Crime       200
# PG-13              Action       152
# R                   Crime       154
# ...                   ...       ...
# PG                 Comedy       116
# PG              Adventure       118
# PG-13              Action       138
# PG                 Horror       114
# R                   Crime       126
#
#                                                       actors_list
# content_rating
# R               [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# R                 [u'Marlon Brando', u'Al Pacino', u'James Caan']
# R               [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# PG-13           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# R               [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ...                                                           ...
# PG              [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# PG              [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# PG-13           [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# PG              [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# R               [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 5 columns]

# %%
movies.reset_index(inplace=True)

# %%
movies.reset_index(inplace=True)

# %%
movies.reset_index(drop=True)
# Out:
#      index content_rating                                            title  \
# 0        0              R                         The Shawshank Redemption
# 1        1              R                                    The Godfather
# 2        2              R                           The Godfather: Part II
# 3        3          PG-13                                  The Dark Knight
# 4        4              R                                     Pulp Fiction
# ..     ...            ...                                              ...
# 974    974             PG                                          Tootsie
# 975    975             PG                      Back to the Future Part III
# 976    976          PG-13  Master and Commander: The Far Side of the World
# 977    977             PG                                      Poltergeist
# 978    978              R                                      Wall Street
#
#      star_rating      genre  duration  \
# 0            9.3      Crime       142
# 1            9.2      Crime       175
# 2            9.1      Crime       200
# 3            9.0     Action       152
# 4            8.9      Crime       154
# ..           ...        ...       ...
# 974          7.4     Comedy       116
# 975          7.4  Adventure       118
# 976          7.4     Action       138
# 977          7.4     Horror       114
# 978          7.4      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 7 columns]

# %%
movies.drop(columns = ['index'], inplace=True)

# %% [markdown]
# ## 2. Sorting a DataFrame

# %% [markdown]
# Documentation for [`sort_values`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html) for a DataFrame

# %%
# sort the entire DataFrame by the 'star_rating' column
movies.sort_values(by='star_rating')
# Out:
#     content_rating                     title  star_rating   genre  duration  \
# 978              R               Wall Street          7.4   Crime       126
# 945              R              Take Shelter          7.4   Drama       120
# 946          PG-13           Far from Heaven          7.4   Drama       107
# 947        UNRATED                Eraserhead          7.4   Drama        89
# 948              R                Frances Ha          7.4  Comedy        86
# ..             ...                       ...          ...     ...       ...
# 4                R              Pulp Fiction          8.9   Crime       154
# 3            PG-13           The Dark Knight          9.0  Action       152
# 2                R    The Godfather: Part II          9.1   Crime       200
# 1                R             The Godfather          9.2   Crime       175
# 0                R  The Shawshank Redemption          9.3   Crime       142
#
#                                            actors_list
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 945  [u'Michael Shannon', u'Jessica Chastain', u'Sh...
# 946  [u'Julianne Moore', u'Dennis Quaid', u'Dennis ...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# ..                                                 ...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
#
# [979 rows x 6 columns]

# %%
# sort in descending order
movies.sort_values(by='star_rating', ascending=False)
# Out:
#     content_rating                                            title  \
# 0                R                         The Shawshank Redemption
# 1                R                                    The Godfather
# 2                R                           The Godfather: Part II
# 3            PG-13                                  The Dark Knight
# 4                R                                     Pulp Fiction
# ..             ...                                              ...
# 958          PG-13                               My Sister's Keeper
# 959              R                             Deconstructing Harry
# 976          PG-13  Master and Commander: The Far Side of the World
# 977             PG                                      Poltergeist
# 978              R                                      Wall Street
#
#      star_rating   genre  duration  \
# 0            9.3   Crime       142
# 1            9.2   Crime       175
# 2            9.1   Crime       200
# 3            9.0  Action       152
# 4            8.9   Crime       154
# ..           ...     ...       ...
# 958          7.4   Drama       109
# 959          7.4  Comedy        96
# 976          7.4  Action       138
# 977          7.4  Horror       114
# 978          7.4   Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 958  [u'Cameron Diaz', u'Abigail Breslin', u'Alec B...
# 959  [u'Woody Allen', u'Judy Davis', u'Julia Louis-...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %% [markdown]
# Sort by *multiple columns*

# %%
# sort the DataFrame first by 'star_rating', then by 'duration'
movies.sort_values(by=['star_rating', 'duration']) # the order does matter
# Out:
#     content_rating                                          title  \
# 938              G                            Alice in Wonderland
# 948              R                                     Frances Ha
# 966          PG-13                             The Simpsons Movie
# 947        UNRATED                                     Eraserhead
# 971              R                             Death at a Funeral
# ..             ...                                            ...
# 7            PG-13  The Lord of the Rings: The Return of the King
# 3            PG-13                                The Dark Knight
# 2                R                         The Godfather: Part II
# 1                R                                  The Godfather
# 0                R                       The Shawshank Redemption
#
#      star_rating      genre  duration  \
# 938          7.4  Animation        75
# 948          7.4     Comedy        86
# 966          7.4  Animation        87
# 947          7.4      Drama        89
# 971          7.4     Comedy        90
# ..           ...        ...       ...
# 7            8.9  Adventure       201
# 3            9.0     Action       152
# 2            9.1      Crime       200
# 1            9.2      Crime       175
# 0            9.3      Crime       142
#
#                                            actors_list
# 938  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 966  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 971  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# ..                                                 ...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
#
# [979 rows x 6 columns]

# %% [markdown]
# By default, `sort_values` will place **NAs** at the end, but you can put it first by setting the parameter `na_position='first'`.

# %%
movies.sort_values(by=['star_rating', 'duration'],  na_position='first') # the order does matter
# Out:
#     content_rating                                          title  \
# 938              G                            Alice in Wonderland
# 948              R                                     Frances Ha
# 966          PG-13                             The Simpsons Movie
# 947        UNRATED                                     Eraserhead
# 971              R                             Death at a Funeral
# ..             ...                                            ...
# 7            PG-13  The Lord of the Rings: The Return of the King
# 3            PG-13                                The Dark Knight
# 2                R                         The Godfather: Part II
# 1                R                                  The Godfather
# 0                R                       The Shawshank Redemption
#
#      star_rating      genre  duration  \
# 938          7.4  Animation        75
# 948          7.4     Comedy        86
# 966          7.4  Animation        87
# 947          7.4      Drama        89
# 971          7.4     Comedy        90
# ..           ...        ...       ...
# 7            8.9  Adventure       201
# 3            9.0     Action       152
# 2            9.1      Crime       200
# 1            9.2      Crime       175
# 0            9.3      Crime       142
#
#                                            actors_list
# 938  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 966  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 971  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# ..                                                 ...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
#
# [979 rows x 6 columns]

# %% [markdown]
# **Sorting with a *key* function:**
#
# We can sort the DataFrame by using a function on a column instead of directly sorting by the values in that column.
#
# Ex: This will sort the dataframe by the length of the "title" column, meaning it arranges the movies based on how many characters are in their titles.

# %%
def movie_len(title):
    return title.str.len()

# %%
movies.sort_values(by='title', key= movie_len )
# Out:
#     content_rating                                              title  \
# 63       NOT RATED                                                  M
# 126             PG                                                 Up
# 871          PG-13                                                 X2
# 824          PG-13                                                 42
# 886              R                                                 Pi
# ..             ...                                                ...
# 10           PG-13  The Lord of the Rings: The Fellowship of the Ring
# 779              R  Interview with the Vampire: The Vampire Chroni...
# 271          PG-13  Pirates of the Caribbean: The Curse of the Bla...
# 807              R  The Assassination of Jesse James by the Coward...
# 48              PG  Dr. Strangelove or: How I Learned to Stop Worr...
#
#      star_rating      genre  duration  \
# 63           8.4      Crime        99
# 126          8.3  Animation        96
# 871          7.5     Action       134
# 824          7.5  Biography       128
# 886          7.5      Drama        84
# ..           ...        ...       ...
# 10           8.8  Adventure       178
# 779          7.6     Horror       123
# 271          8.1  Adventure       143
# 807          7.6  Biography       160
# 48           8.5     Comedy        95
#
#                                            actors_list
# 63   [u'Peter Lorre', u'Ellen Widmann', u'Inge Land...
# 126  [u'Edward Asner', u'Jordan Nagai', u'John Ratz...
# 871  [u'Patrick Stewart', u'Hugh Jackman', u'Halle ...
# 824  [u'Chadwick Boseman', u'T.R. Knight', u'Harris...
# 886  [u'Sean Gullette', u'Mark Margolis', u'Ben She...
# ..                                                 ...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 779  [u'Brad Pitt', u'Tom Cruise', u'Antonio Bander...
# 271  [u'Johnny Depp', u'Geoffrey Rush', u'Orlando B...
# 807   [u'Brad Pitt', u'Casey Affleck', u'Sam Shepard']
# 48   [u'Peter Sellers', u'George C. Scott', u'Sterl...
#
# [979 rows x 6 columns]

# %% [markdown]
# When we sorted the data, we actually made a copy. So, if you check the original data, it won't be sorted.

# %% [markdown]
# To change the original dataframe, you need to set `inplace=True` when sorting. This means the sorting directly alters the original data. If you leave `inplace` as `False`, it creates a sorted copy without changing the original data (this is the default).
